# %%
print("Hello")
print("while")
# Out:
# Hello
# while

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# we have added some sorts of model excecutive for our bussiness

# %%
print("hello")
# Out:
# hello
